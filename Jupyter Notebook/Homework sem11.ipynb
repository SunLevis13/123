# %%
import sympy as sp
from sympy import*
import math as m
import matplotlib.pyplot as plt
import numpy
from sympy.plotting import plot

# %%
x = sp.Symbol('x')
func = -12*x**4*sp.sin(sp.cos(x)) - 18*x**3+5*x**2 + 10*x - 30
func
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
f_diff = func.diff(x)
print(f_diff)
# Out:
# 12*x**4*sin(x)*cos(cos(x)) - 48*x**3*sin(cos(x)) - 54*x**2 + 10*x + 10

# %%
plot(func,(x,-200,200))
func
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
h = solve(-12*x**4*sp.sin(sp.cos(x)))
h
# Out:
# [0, pi/2, 3*pi/2, 2*pi - acos(pi), acos(pi)]

# %%
roots = solve(h[1] - 18*x**3+5*x**2 + 10*x - 30)
print("Корни: ", roots)
# Out:
# Корни:  [5/54 - 565/(972*(-1/2 - sqrt(3)*I/2)*(-3*pi/8 + sqrt(-180362125/8503056 + (127045/2916 - 3*pi/4)**2)/2 + 127045/5832)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(-3*pi/8 + sqrt(-180362125/8503056 + (127045/2916 - 3*pi/4)**2)/2 + 127045/5832)**(1/3)/3, 5/54 - (-1/2 + sqrt(3)*I/2)*(-3*pi/8 + sqrt(-180362125/8503056 + (127045/2916 - 3*pi/4)**2)/2 + 127045/5832)**(1/3)/3 - 565/(972*(-1/2 + sqrt(3)*I/2)*(-3*pi/8 + sqrt(-180362125/8503056 + (127045/2916 - 3*pi/4)**2)/2 + 127045/5832)**(1/3)), -(-3*pi/8 + sqrt(-180362125/8503056 + (127045/2916 - 3*pi/4)**2)/2 + 127045/5832)**(1/3)/3 - 565/(972*(-3*pi/8 + sqrt(-180362125/8503056 + (127045/2916 - 3*pi/4)**2)/2 + 127045/5832)**(1/3)) + 5/54]

# %%
def inner_func():
        print('hello my friend')
return inner_func()

# %%
a = inner_func()
